# %% [markdown]
# # <center>**SPECTRUM INTENSHIP DRIVE 2021.**</center>
#
# ## <center>**Welcome to the Final task of DS/ML internship of SID 2021.**</center>

# %% [markdown]
# ### <center>In the final task we will be learning about various machine learning pipelines starting from fetching data , preprocessing them , feature selection to building models using **3 REGRESSION algorithms (LINEAR REGRESSION, DECISION TREE REGRESSION, RANDOM FOREST REGRESSION)** and comparing their R Squared score and **3 CLASSIFICATION machine learning algorithms (LOGISTIC REGRESSION, DECISION TREE CLASSIFICATION, RANDOM FOREST CLASSIFICATION)** and comparing their accuracy.

# %% [markdown]
# ![Screenshot (176).png](data:image/png;base64,...)

# %% [markdown]
# #### **Perform the following on the dataset:**
# (not necessarily in the same sequence)
#
# - Exploratory data analysis
#
# - Handle the missing values.
#
# - Make a new column called SalePriceClass,  based on the following conditions.
#
#   - if SalePrice greater than or equal 400000 then SalePriceClass = 'A'
#   - if SalePrice between 300000 and 399999 then SalePriceClass = 'B'
#   - if SalePrice between 200000 and 299999 then SalePriceClass = 'C'
#   - if SalePrice between 100000 and 199999 then SalePriceClass = 'D'
#   - if SalePrice less than or equal 100000 then SalePriceClass = 'E'
#
# - Label Encoding
#
# - Feature Selection
#
# - Outlier detection  and removal.
#
# - Data Scaling
#
# - Spliting the data into train and test set.
#
# - Make use of 3 REGRESSION machine learning algorithms (LINEAR REGRESSION ,DECISION TREE REGRESSION, RANDOM FOREST REGRESSION) and compare their R Squared score.(**Target variable - SalePrice**)
#
# - Make use of 3 CLASSIFICATION machine learning algorithms (LOGISTIC REGRESSION ,DECISION TREE CLASSIFICATION, RANDOM FOREST CLASSIFICATION) and compare their accuracy.(**Target variable - SalePriceClass**)
#
# - Try to optimize hyperparameters using RandomizedSearchCV or GridSearchCV.
#
# - Find the best algorithm for Regression and Classification on the given dataset.
#
# **NOTE-Make sure to make use of markdowns and comments.**

# %% [markdown]
# #### **Resources**
#
# Watching:
# - [The 7 steps of machine learning](https://www.youtube.com/watch?v=nKW8Ndu7Mjw)
# - [How to Build a Machine Learning Model](https://www.youtube.com/watch?v=NRnaMCNOK7Y)
# - [StatQuest: Fitting a line to data, aka least squares, aka linear regression.](https://www.youtube.com/watch?v=PaFPbb66DxQ&list=PLblh5JKOoLUIzaEkCLIUxQFjPIlapw8nU&index=1)
# - [Linear Regression](https://youtu.be/E5RjzSK0fvY)
# - [Logistic Regression](https://www.youtube.com/watch?v=XnOAdxOWXWg)
# - [Decision Tree](https://youtu.be/qDcl-FRnwSU)
# - [Random Forest](https://youtu.be/ok2s1vV9XW0)
# - [Regression Trees, Clearly Explained!!!](https://www.youtube.com/watch?v=g9c66TUylZ4&list=PLblh5JKOoLUKAtDViTvRGFpphEc24M-QH&index=3)
#
# Reading:
#
# - [Data Preprocessing from hackernoon](https://hackernoon.com/what-steps-should-one-take-while-doing-data-preprocessing-502c993e1caa)
# - [Data PreProcessing from datadriveninvestor](https://medium.datadriveninvestor.com/data-science-data-preprocessing-eda-6be2860fbb5d)
# - [The 7 Steps of Machine Learning from towardsdatascience](https://towardsdatascience.com/the-7-steps-of-machine-learning-2877d7e5548e)
# - [The Ultimate Guide to Linear Regression for Machine Learning](https://www.keboola.com/blog/linear-regression-machine-learning)
# - [Decision Trees and Random Forests](https://towardsdatascience.com/decision-trees-and-random-forests-df0c3123f991)
# - [Decision Trees and Random Forests — Explained](https://towardsdatascience.com/decision-tree-and-random-forest-explained-8d20ddabc9dd)
# - [Evaluation Metrics for Regression Model](https://www.analyticsvidhya.com/blog/2021/05/know-the-best-evaluation-metrics-for-your-regression-model/)
# - [Hyperparameter tuning with GridSearchCV and RandomizedSearchCV](https://towardsdatascience.com/machine-learning-gridsearchcv-randomizedsearchcv-d36b89231b10)
# - [Random Search to Optimize Hyperparameters](https://www.section.io/engineering-education/random-search-hyperparameters/)

# %% [markdown]
# ### NOTE-The below layout is made just for convenience. Add or delete cells and sub-sections according to your own requirement

# %% [markdown]
# # Loading Data

# %%
# Run this cell to download the dataset required for this task
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp' -O 'final_task.csv'
# Out:
# --2021-07-28 14:01:12--  https://docs.google.com/uc?export=download&id=1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp
# Resolving docs.google.com (docs.google.com)... 2404:6800:4009:82c::200e, 142.250.183.174
# Connecting to docs.google.com (docs.google.com)|2404:6800:4009:82c::200e|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-ak-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ebdkot1rah5vv8ujthd5e2vadf0c0459/1627461000000/03131713557125907988/*/1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp?e=download [following]
# ...
# --2021-07-28 14:01:15--  https://doc-14-ak-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ebdkot1rah5vv8ujthd5e2vadf0c0459/1627461000000/03131713557125907988/*/1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp?e=download
# Resolving doc-14-ak-docs.googleusercontent.com (doc-14-ak-docs.googleusercontent.com)... 2404:6800:4009:809::2001, 216.58.196.65
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
df = pd.read_csv('final_task.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Creating a column for SalePriceClass

# %%
def SalePriceClass(df):
   if (df['SalePrice'] >= 400000):
      return 'A'
   elif (df['SalePrice'] >= 300000 and df['SalePrice']<400000):
      return 'B'
   elif (df['SalePrice'] >= 200000 and df['SalePrice']<300000):
      return 'C'
   elif (df['SalePrice'] >100000 and df['SalePrice']<200000):
      return 'D'
   elif (df['SalePrice'] <= 100000):
      return 'E'

# %%
df['SalePriceClass'] = df.apply (lambda df: SalePriceClass(df), axis=1)

# %%
df['SalePriceClass'].value_counts()
# Out:
# D    902
# C    320
# E    123
# B     87
# A     28
# Name: SalePriceClass, dtype: int64

# %% [markdown]
# # Understanding and handling data

# %%
df = df.drop('Id',axis =1)
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
pd.options.display.max_rows = 500
def percent_missing_data(df):
    missing_count = df.isna().sum().sort_values(ascending = False)
    missing_percent = 100 * df.isna().sum().sort_values(ascending = False) / len(df)
   
    
    missing_count = pd.DataFrame(missing_count[missing_count > 0])
    missing_percent = pd.DataFrame(missing_percent[missing_percent > 0])
    
    missing_table = pd.concat([missing_count,missing_percent], axis = 1)
    missing_table.columns = ["missing_count", "missing_percent"]
    
    return missing_table

# %%
missing_values = percent_missing_data(df)
missing_values
# Out:
#               missing_count  missing_percent
# PoolQC                 1453        99.520548
# MiscFeature            1406        96.301370
# Alley                  1369        93.767123
# Fence                  1179        80.753425
# FireplaceQu             690        47.260274
# LotFrontage             259        17.739726
# GarageYrBlt              81         5.547945
# GarageQual               81         5.547945
# GarageFinish             81         5.547945
# GarageCond               81         5.547945
# GarageType               81         5.547945
# BsmtFinType2             38         2.602740
# BsmtExposure             38         2.602740
# BsmtCond                 37         2.534247
# BsmtQual                 37         2.534247
# BsmtFinType1             37         2.534247
# MasVnrType                8         0.547945
# MasVnrArea                8         0.547945
# Electrical                1         0.068493

# %%
df_object = df.select_dtypes(include = "object")
df_numeric = df.select_dtypes(exclude = "object")
df_object.shape , df_numeric.shape
# Out:
# ((1460, 44), (1460, 37))

# %%
df_object = df_object.drop('SalePriceClass',axis =1)
df_object.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
# ...

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    Inside  ...    NaN   NaN         NaN       0
# 1         Lvl    AllPub       FR2  ...    NaN   NaN         NaN       0
# 2         Lvl    AllPub    Inside  ...    NaN   NaN         NaN       0
# 3         Lvl    AllPub    Corner  ...    NaN   NaN         NaN       0
# 4         Lvl    AllPub       FR2  ...    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice  SalePriceClass
# ...

# %% [markdown]
# # EDA

# %%
# Check for Corelation between Features
plt.figure(figsize=(20, 10))
sns.heatmap(df.corr(),yticklabels=True,cbar=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.corr()["SalePrice"].sort_values(ascending = False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %% [markdown]
# Here we can see that 'OverAllQual' is most corelated with 'SalePrice'.
# Lets explore highly correlated features with 'Sale Price'.

# %%
sns.scatterplot(data = df, x = "OverallQual", y = "SalePrice")
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.scatterplot(data = df, x = "GrLivArea", y = "SalePrice");

# %%
sns.scatterplot(data = df, x = "GarageCars", y = "SalePrice");

# %%
sns.scatterplot(data = df, x = "GarageArea", y = "SalePrice");

# %% [markdown]
# We can see that there are houses with higher(10/10) quality but have very low prices.
#
# There are high prices for larger living areas, but we can see some of the outliers also.Same goes for Garage Area too.
#
# Number of garage cars also tend to follow the trend where higher the amount of cars is propotional to higher Sales Price.(Highest number 4 can be counted as exceptional)

# %% [markdown]
# We can divide numerical data into three types
#
#
# *  Continous variable
# *  Discrete Variables
# *  Date-time or Temporal variable

# %%
# list of variables that contain year information
year_feature = [feature for feature in df_numeric if 'Yr' in feature or 'Year' in feature]
print("Temporial feature Count : {}".format(len(year_feature)))
year_feature
# Out:
# Temporial feature Count : 4
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
## Visualising the Temporal Datetime Variables
## We will check whether there is a relation between year the house is sold and the sales price

df.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title("House Price vs YearSold")
# Out:
# Text(0.5, 1.0, 'House Price vs YearSold')

# %% [markdown]
# we can see that house price is decreasing with time

# %%
#Discrete Features
discrete_feature=[feature for feature in df_numeric if len(df[feature].unique())<25 and feature not in year_feature+['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 17

# %%
#Continous Features
continuous_feature=[feature for feature in df_numeric if feature not in discrete_feature+year_feature+['Id']]
print("Continuous feature Count: {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count: 16

# %% [markdown]
# Checking for outiners

# %%
for feature in continuous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# # Feature Engineering

# %%
missing_values = percent_missing_data(df)
missing_values
# Out:
#               missing_count  missing_percent
# PoolQC                 1453        99.520548
# MiscFeature            1406        96.301370
# Alley                  1369        93.767123
# Fence                  1179        80.753425
# FireplaceQu             690        47.260274
# LotFrontage             259        17.739726
# GarageYrBlt              81         5.547945
# GarageQual               81         5.547945
# GarageFinish             81         5.547945
# GarageCond               81         5.547945
# GarageType               81         5.547945
# BsmtFinType2             38         2.602740
# BsmtExposure             38         2.602740
# BsmtCond                 37         2.534247
# BsmtQual                 37         2.534247
# BsmtFinType1             37         2.534247
# MasVnrType                8         0.547945
# MasVnrArea                8         0.547945
# Electrical                1         0.068493

# %%
plt.figure(figsize=(10,4), dpi = 100)
sns.barplot(x=missing_values.index,y='missing_percent', data=missing_values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can see column **'PoolQC'** has maximum missing values.We can either drop it or decide to keep it if the feature is important for our model.
# But first, we can deal with features that have less missing values.ie. less than 1% missing values.

# %%
#Extracting Features that have less than 1% missing values
missing_values[missing_values['missing_percent']<1]
# Out:
#             missing_count  missing_percent
# MasVnrType              8         0.547945
# MasVnrArea              8         0.547945
# Electrical              1         0.068493

# %%
#Electrical has only 1 missing value.It can be filled with mode
df['Electrical'].mode()
# Out:
# 0    SBrkr
# dtype: object

# %%
df['Electrical'] = df['Electrical'].fillna('SBrkr')
df['Electrical'].isna().sum()
# Out:
# 0

# %%
#'MasVnrArea' & 'MasVnrType' also have less than 1% missing values.

df['MasVnrArea'].value_counts(), df['MasVnrType'].value_counts()
# Out:
# (0.0       861
#  108.0       8
#  72.0        8
#  180.0       8
#  16.0        7
#  120.0       7
#  340.0       6
#  106.0       6
#  200.0       6
#  80.0        6
#  84.0        5
#  360.0       5
#  132.0       5
#  170.0       5
#  320.0       5
#  270.0       4
#  336.0       4
#  216.0       4
#  252.0       4
#  268.0       4
#  183.0       4
#  100.0       4
#  196.0       4
#  220.0       4
#  40.0        4
#  456.0       4
#  76.0        4
#  300.0       4
#  210.0       4
#  246.0       4
#  288.0       4
#  168.0       4
#  160.0       4
#  178.0       4
#  50.0        3
#  350.0       3
#  240.0       3
#  226.0       3
#  42.0        3
#  420.0       3
#  90.0        3
#  169.0       3
#  272.0       3
#  136.0       3
#  116.0       3
#  166.0       3
#  99.0        3
#  110.0       3
#  176.0       3
#  130.0       3
#  312.0       3
#  186.0       3
#  148.0       3
#  174.0       3
#  128.0       3
#  104.0       3
#  82.0        3
#  208.0       3
# ...

# %%
#From the above we can see that 'MasVnrArea' has values with 0, so missing values can be filled with '0'.
# 'MasType' has category for None, so missing values can be filled with 'None'.

df['MasVnrArea']= df['MasVnrArea'].fillna(0)
df['MasVnrType']= df['MasVnrType'].fillna('None')

# %%
missing_values = percent_missing_data(df)
missing_values
# Out:
#               missing_count  missing_percent
# PoolQC                 1453        99.520548
# MiscFeature            1406        96.301370
# Alley                  1369        93.767123
# Fence                  1179        80.753425
# FireplaceQu             690        47.260274
# LotFrontage             259        17.739726
# GarageType               81         5.547945
# GarageCond               81         5.547945
# GarageQual               81         5.547945
# GarageFinish             81         5.547945
# GarageYrBlt              81         5.547945
# BsmtFinType2             38         2.602740
# BsmtExposure             38         2.602740
# BsmtFinType1             37         2.534247
# BsmtQual                 37         2.534247
# BsmtCond                 37         2.534247

# %% [markdown]
# All the Basement related features have 2% missing values.
#
# By going through data,we can find that Nan actually means that the house do not has a basement.So we can replace Nan values with 'None' which means no basement.
#
# For Basement related numeric columns we will replace Nan values with zero.

# %%
# basement string features ==> fill with none
bsmt_str_cols =  ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
df[bsmt_str_cols] = df[bsmt_str_cols].fillna('None')

# basement numeric features ==> fill with 0
bsmt_num_cols = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath']
df[bsmt_num_cols] = df[bsmt_num_cols].fillna(0)

# %%
missing_values = percent_missing_data(df)
missing_values
# Out:
#               missing_count  missing_percent
# PoolQC                 1453        99.520548
# MiscFeature            1406        96.301370
# Alley                  1369        93.767123
# Fence                  1179        80.753425
# FireplaceQu             690        47.260274
# LotFrontage             259        17.739726
# GarageQual               81         5.547945
# GarageType               81         5.547945
# GarageFinish             81         5.547945
# GarageCond               81         5.547945
# GarageYrBlt              81         5.547945

# %% [markdown]
# Here all the Garage related features has around 5% missing values.
#
# We can fill those categories using mean and mode.(mean for numerical features and mode for categorical features)

# %%
# Mode                                           
print(df.GarageType.mode() )   
print(df.GarageCond.mode()) 
print(df.GarageFinish.mode() )
print(df.GarageQual.mode() )
# Out:
# 0    Attchd
# dtype: object
# 0    TA
# dtype: object
# 0    Unf
# dtype: object
# 0    TA
# dtype: object

# %%
# Garage string features ==> fill with Mode                                           
df['GarageType']= df['GarageType'].fillna('Attchd')    
df['GarageCond']= df['GarageCond'].fillna('TA') 
df['GarageFinish']= df['GarageFinish'].fillna('Unf') 
df['GarageQual']= df['GarageQual'].fillna('TA') 

# basement numeric features ==> fill with Mean
df['GarageYrBlt']= df['GarageYrBlt'].fillna(df.GarageYrBlt.mean())

# %%
missing_values = percent_missing_data(df)
missing_values
# Out:
#              missing_count  missing_percent
# PoolQC                1453        99.520548
# MiscFeature           1406        96.301370
# Alley                 1369        93.767123
# Fence                 1179        80.753425
# FireplaceQu            690        47.260274
# LotFrontage            259        17.739726

# %% [markdown]
# The columns has more than **80%** missing values. It is best option to drop them.

# %%
# Dropping columns with more than 80% missing values.
df = df.drop(["PoolQC", "MiscFeature", "Alley", "Fence"], axis = 1)

# %%
df['FireplaceQu'].value_counts() , df['LotFrontage'].value_counts()
# Out:
# (Gd    380
#  TA    313
#  Fa     33
#  Ex     24
#  Po     20
#  Name: FireplaceQu, dtype: int64,
#  60.0     143
#  70.0      70
#  80.0      69
#  50.0      57
#  75.0      53
#  65.0      44
#  85.0      40
#  78.0      25
#  90.0      23
#  21.0      23
#  64.0      19
#  68.0      19
#  24.0      19
#  73.0      18
#  79.0      17
#  55.0      17
#  72.0      17
#  63.0      17
#  100.0     16
#  74.0      15
#  66.0      15
#  51.0      15
#  52.0      14
#  59.0      13
#  82.0      12
#  43.0      12
#  40.0      12
#  71.0      12
#  67.0      12
#  57.0      12
#  76.0      11
#  69.0      11
#  92.0      10
#  53.0      10
#  88.0      10
#  34.0      10
#  86.0      10
#  84.0       9
#  77.0       9
#  35.0       9
#  44.0       9
#  62.0       9
#  61.0       8
#  98.0       8
#  96.0       8
#  93.0       8
#  58.0       7
#  120.0      7
#  95.0       7
#  107.0      7
#  91.0       6
#  110.0      6
#  41.0       6
#  81.0       6
#  89.0       6
#  30.0       6
# ...

# %% [markdown]
# 'FireplaceQu' is categorical column, so missing values can be filled with 'None'.
#
# But, 'LotFrontage' is numerical column and it also has outliers, so it can be filled with median.

# %%
df['FireplaceQu']= df['FireplaceQu'].fillna('None')    
df['LotFrontage']= df['LotFrontage'].fillna(df.LotFrontage.median())

# %%
missing_values = percent_missing_data(df)
missing_values
# Out:
# Empty DataFrame
# Columns: [missing_count, missing_percent]
# Index: []

# %% [markdown]
# Hence, there is no missing values in the dataset.

# %%
df_object = df.select_dtypes(include = "object")
df_numeric = df.select_dtypes(exclude = "object")
df_object.shape , df_numeric.shape
# Out:
# ((1460, 40), (1460, 37))

# %%
df_object = df_object.drop('SalePriceClass',axis =1)
df_object.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2  ... KitchenQual Functional FireplaceQu  \
# 0      CollgCr       Norm       Norm  ...          Gd        Typ        None
# 1      Veenker      Feedr       Norm  ...          TA        Typ          TA
# 2      CollgCr       Norm       Norm  ...          Gd        Typ          TA
# 3      Crawfor       Norm       Norm  ...          Gd        Typ          Gd
# 4      NoRidge       Norm       Norm  ...          Gd        Typ          TA
#
#   GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# ...

# %% [markdown]
# # Feature Selection

# %%
df.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.356718 -0.139781     0.032628    -0.059316
# LotFrontage     -0.356718     1.000000  0.304522     0.234812    -0.053281
# LotArea         -0.139781     0.304522  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.234812  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.053281 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.116685  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.083348  0.013788     0.550684     0.073741
# MasVnrArea       0.023573     0.178469  0.103321     0.407252    -0.125694
# BsmtFinSF1      -0.069836     0.214367  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.042463  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.124098 -0.002618     0.308159    -0.136841
# ...

# %%
df.corr()["SalePrice"].sort_values(ascending = False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.472614
# GarageYrBlt      0.470177
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.334771
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %% [markdown]
# **Numerical Feature**

# %%
df_numeric
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %% [markdown]
# numerical variables are skewed,so we can perform log normal distribution to prevent negative predictions.
#
# We will only perform log normal distribution to columns which do not have any zero values.

# %%
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    df[feature]=np.log(df[feature])

# %%
df_numeric
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %% [markdown]
# **Categorical Features**

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 0          60       RL     4.174387  9.041922   Pave      Reg         Lvl
# 1          20       RL     4.382027  9.169518   Pave      Reg         Lvl
# 2          60       RL     4.219508  9.328123   Pave      IR1         Lvl
# 3          70       RL     4.094345  9.164296   Pave      IR1         Lvl
# 4          60       RL     4.430817  9.565214   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... 3SsnPorch ScreenPorch PoolArea MiscVal  \
# 0    AllPub    Inside       Gtl  ...         0           0        0       0
# 1    AllPub       FR2       Gtl  ...         0           0        0       0
# 2    AllPub    Inside       Gtl  ...         0           0        0       0
# 3    AllPub    Corner       Gtl  ...         0           0        0       0
# 4    AllPub       FR2       Gtl  ...         0           0        0       0
#
# ...

# %%
#  Converting categorical features into numerical
for feature in df_object:
    labels_ordered=df.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    df[feature]=df[feature].map(labels_ordered)

# %%
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  LandContour  \
# 0          60         3     4.174387  9.041922       1         0            1
# 1          20         3     4.382027  9.169518       1         0            1
# 2          60         3     4.219508  9.328123       1         1            1
# 3          70         3     4.094345  9.164296       1         1            1
# 4          60         3     4.430817  9.565214       1         1            1
#
#    Utilities  LotConfig  LandSlope  ...  3SsnPorch  ScreenPorch  PoolArea  \
# 0          1          0          0  ...          0            0         0
# 1          1          2          0  ...          0            0         0
# 2          1          0          0  ...          0            0         0
# 3          1          1          0  ...          0            0         0
# 4          1          2          0  ...          0            0         0
#
# ...

# %% [markdown]
# DATA SCALING

# %% [markdown]
# For Regression Models

# %%
X = df.drop(['SalePriceClass','SalePrice'],axis=1)
Y = df['SalePrice']

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %%
# Standard scaling our data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train) 
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape , X_test.shape
# Out:
# ((1022, 75), (438, 75))

# %% [markdown]
# For Classification Models

# %%
X1 = df.drop(['SalePriceClass'],axis=1)
Y1 = df['SalePriceClass']

# %%
# Train test split
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(X1, Y1, test_size=0.3, random_state=101)

# %%
scaler.fit(X_train1) 
X_train1 = scaler.transform(X_train1)
X_test1 = scaler.transform(X_test1)

# %%
X_train1.shape , X_test1.shape
# Out:
# ((1022, 76), (438, 76))

# %% [markdown]
# # Model Building

# %% [markdown]
# #### REGRESSION

# %% [markdown]
# 1)LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = LR.predict(X_test)
p1= LR.score(X_test, Y_test)

# %%
plt.figure(figsize=(10,8))
sns.regplot(x = Y_pred, y = Y_test)
# Out:
# <AxesSubplot:ylabel='SalePrice'>

# %% [markdown]
# 2)DECISION TREE REGRESSION

# %%
from sklearn import tree

clf = tree.DecisionTreeRegressor()
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
Y_pred = clf.predict(X_test)
p2= clf.score(X_test, Y_test)

# %%
plt.figure(figsize=(10,8))
sns.regplot(x = Y_pred, y = Y_test)
# Out:
# <AxesSubplot:ylabel='SalePrice'>

# %% [markdown]
# 3)RANDOM FOREST REGRESSION

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_pred = rf.predict(X_test)
p3= rf.score(X_test, Y_test)

# %%
plt.figure(figsize=(10,8))
sns.regplot(x = Y_pred, y = Y_test)
# Out:
# <AxesSubplot:ylabel='SalePrice'>

# %% [markdown]
# Comparision between Three Regression Model's Prediction

# %%
name = ('Linear Regression', 'Decission Tree Regressor','RandomForestRegressor')
score = (p1,p2,p3)

# %%
dfc = pd.DataFrame()
dfc['Name']= name
dfc['Score']= score
dfc
# Out:
#                        Name     Score
# 0         Linear Regression  0.864492
# 1  Decission Tree Regressor  0.712455
# 2     RandomForestRegressor  0.859094

# %%
sns.barplot(x = "Name", y = 'Score', data = dfc, palette = 'viridis')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the above graph and table we can conclude that Linear regression is the best model for this dataset for regression which has the score of about 86%

# %% [markdown]
# #### CLASSIFICATION

# %% [markdown]
# 1)Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
lg = LogisticRegression(max_iter=1000)
lg.fit(X_train1, Y_train1)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred1 = lg.predict(X_test1)
c1= lg.score(X_test1, Y_test1)

# %% [markdown]
# 2)Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train1, Y_train1)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred1 = dtc.predict(X_test1)
c2= dtc.score(X_test1, Y_test1)

# %% [markdown]
# 3)Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train1, Y_train1)
# Out:
# RandomForestClassifier()

# %%
Y_pred1 = rfc.predict(X_test1)
c3= rfc.score(X_test1, Y_test1)

# %% [markdown]
# Comparision between Three Regression Model's Prediction

# %%
name = ('Linear Classification', 'Decission Tree Classification','RandomForest Classification')
score = (c1,c2,c3)

# %%
dfc = pd.DataFrame()
dfc['Name']= name
dfc['Score']= score
dfc
# Out:
#                             Name     Score
# 0          Linear Classification  0.865297
# 1  Decission Tree Classification  1.000000
# 2    RandomForest Classification  0.961187

# %%
sns.barplot(x = "Name", y = 'Score', data = dfc, palette = 'viridis')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the above graph and table we can conclude that Decission Tree Classification is the best model for this dataset for regression which has the score of about 100%

# %% [markdown]
# ## <center>**GOOD JOB!!!**
# ## <center> WITH YOUR DEDICATION AND PERSISTENCE YOU FINALLY MADE IT TO THE END AND COMPLETED THIS INTERNSHIP.
# ## <center> BUT THIS IS JUST THE BEGINNING .KEEP EXPLORING AND LEARNING.
#
# ## <center> **HAPPY MACHINE LEARNING!!!**
